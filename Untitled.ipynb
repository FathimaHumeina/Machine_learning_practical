# %%
import pandas as pd

# %%
heart=pd.read_csv('heart.csv')

# %%
heart
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
heart.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
heart.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
heart[heart.Age>heart.Age.mean()+(3*heart.Age.std())]
# Out:
# Empty DataFrame
# Columns: [Age, Sex, ChestPainType, RestingBP, Cholesterol, FastingBS, RestingECG, MaxHR, ExerciseAngina, Oldpeak, ST_Slope, HeartDisease]
# Index: []

# %%
heart[heart.Age<heart.Age.mean()-(3*heart.Age.std())]
# Out:
# Empty DataFrame
# Columns: [Age, Sex, ChestPainType, RestingBP, Cholesterol, FastingBS, RestingECG, MaxHR, ExerciseAngina, Oldpeak, ST_Slope, HeartDisease]
# Index: []

# %%
heart[heart.RestingBP>heart.RestingBP.mean()+(3*heart.RestingBP.std())]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 109   39   M           ATA        190          241          0     Normal
# 241   54   M           ASY        200          198          0     Normal
# 365   64   F           ASY        200            0          0     Normal
# 399   61   M           NAP        200            0          1         ST
# 592   61   M           ASY        190          287          1        LVH
# 732   56   F           ASY        200          288          1        LVH
# 759   54   M           ATA        192          283          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 109    106              N      0.0       Up             0
# 241    142              Y      2.0     Flat             1
# 365    140              Y      1.0     Flat             1
# 399     70              N      0.0     Flat             1
# 592    150              Y      2.0     Down             1
# ...

# %%
heart1=heart[heart.RestingBP<heart.RestingBP.mean()+(3*heart.RestingBP.std())]

# %%
heart1
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
heart[heart.RestingBP<heart.RestingBP.mean()-(3*heart.RestingBP.std())]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 449   55   M           NAP          0            0          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 449    155              N      1.5     Flat             1

# %%
heart2=heart1[heart1.RestingBP>heart1.RestingBP.mean()-(3*heart1.RestingBP.std())]

# %%
heart2
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
heart[heart.Cholesterol>heart.Cholesterol.mean()+(3*heart.Cholesterol.std())]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 76    32   M           ASY        118          529          0     Normal
# 149   54   M           ASY        130          603          1     Normal
# 616   67   F           NAP        115          564          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 76     130              N      0.0     Flat             1
# 149    125              Y      1.0     Flat             1
# 616    160              N      1.6     Flat             0

# %%
heart3=heart2[heart2.Cholesterol<heart2.Cholesterol.mean()+(3*heart2.Cholesterol.std())]

# %%
heart3
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
heart[heart.Cholesterol<heart.Cholesterol.mean()-(3*heart.Cholesterol.std())]
# Out:
# Empty DataFrame
# Columns: [Age, Sex, ChestPainType, RestingBP, Cholesterol, FastingBS, RestingECG, MaxHR, ExerciseAngina, Oldpeak, ST_Slope, HeartDisease]
# Index: []

# %%
heart[heart.FastingBS>heart.FastingBS.mean()+(3*heart.FastingBS.std())]
# Out:
# Empty DataFrame
# Columns: [Age, Sex, ChestPainType, RestingBP, Cholesterol, FastingBS, RestingECG, MaxHR, ExerciseAngina, Oldpeak, ST_Slope, HeartDisease]
# Index: []

# %%
heart[heart.FastingBS<heart.FastingBS.mean()-(3*heart.FastingBS.std())]
# Out:
# Empty DataFrame
# Columns: [Age, Sex, ChestPainType, RestingBP, Cholesterol, FastingBS, RestingECG, MaxHR, ExerciseAngina, Oldpeak, ST_Slope, HeartDisease]
# Index: []

# %%
heart[heart.MaxHR>heart.MaxHR.mean()+(3*heart.MaxHR.std())]
# Out:
# Empty DataFrame
# Columns: [Age, Sex, ChestPainType, RestingBP, Cholesterol, FastingBS, RestingECG, MaxHR, ExerciseAngina, Oldpeak, ST_Slope, HeartDisease]
# Index: []

# %%
heart[heart.MaxHR<heart.MaxHR.mean()-(3*heart.MaxHR.std())]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 390   51   M           ASY        140            0          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 390     60              N      0.0     Flat             1

# %%
heart4=heart3[heart3.MaxHR>heart3.MaxHR.mean()-(3*heart3.MaxHR.std())]

# %%
heart4
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
heart[heart.Oldpeak>heart.Oldpeak.mean()+(3*heart.Oldpeak.std())]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 166   50   M           ASY        140          231          0         ST
# 702   59   M            TA        178          270          0        LVH
# 771   55   M           ASY        140          217          0     Normal
# 791   51   M           ASY        140          298          0     Normal
# 850   62   F           ASY        160          164          0        LVH
# 900   58   M           ASY        114          318          0         ST
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 166    140              Y      5.0     Flat             1
# 702    145              N      4.2     Down             0
# 771    111              Y      5.6     Down             1
# 791    122              Y      4.2     Flat             1
# 850    145              N      6.2     Down             1
# 900    140              N      4.4     Down             1

# %%
heart5=heart4[heart4.Oldpeak<heart4.Oldpeak.mean()+(3*heart4.Oldpeak.std())]

# %%
heart5
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
heart[heart.Oldpeak<heart.Oldpeak.mean()-(3*heart.Oldpeak.std())]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 324   46   M           ASY        100            0          1         ST
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 324    133              N     -2.6     Flat             1

# %%
heart6=heart5[heart5.Oldpeak>heart5.Oldpeak.mean()-(3*heart5.Oldpeak.std())]

# %%
heart6
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
heart[heart.HeartDisease>heart.HeartDisease.mean()+(3*heart.HeartDisease.std())]
# Out:
# Empty DataFrame
# Columns: [Age, Sex, ChestPainType, RestingBP, Cholesterol, FastingBS, RestingECG, MaxHR, ExerciseAngina, Oldpeak, ST_Slope, HeartDisease]
# Index: []

# %%
heart[heart.HeartDisease<heart.HeartDisease.mean()-(3*heart.HeartDisease.std())]
# Out:
# Empty DataFrame
# Columns: [Age, Sex, ChestPainType, RestingBP, Cholesterol, FastingBS, RestingECG, MaxHR, ExerciseAngina, Oldpeak, ST_Slope, HeartDisease]
# Index: []

# %%
heart6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 899 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             899 non-null    int64
#  1   Sex             899 non-null    object
#  2   ChestPainType   899 non-null    object
#  3   RestingBP       899 non-null    int64
#  4   Cholesterol     899 non-null    int64
#  5   FastingBS       899 non-null    int64
#  6   RestingECG      899 non-null    object
#  7   MaxHR           899 non-null    int64
#  8   ExerciseAngina  899 non-null    object
#  9   Oldpeak         899 non-null    float64
#  10  ST_Slope        899 non-null    object
#  11  HeartDisease    899 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 91.3+ KB

# %%
heart6['Sex'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
heart6['ChestPainType'].unique()
# Out:
# array(['ATA', 'NAP', 'ASY', 'TA'], dtype=object)

# %%
heart6['RestingECG'].unique()
# Out:
# array(['Normal', 'ST', 'LVH'], dtype=object)

# %%
heart6['ExerciseAngina'].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
heart6['ST_Slope'].unique()
# Out:
# array(['Up', 'Flat', 'Down'], dtype=object)

# %%
heart7=heart5.copy()

# %%
heart7.ChestPainType.replace({
    'ATA':1,
    'NAP':2,
    'ASY':3,
    'TA':4
},inplace=True)

heart7.RestingECG.replace({
    'Normal':1,
    'ST':2,
    'LVH':3
},inplace=True)

heart7.ExerciseAngina.replace({
    'N':0,
    'Y':1
},inplace=True)

heart7.ST_Slope.replace({
    'Up':1,
    'Flat':2,
    'Down':3
},inplace=True)

# %%
heart_final=pd.get_dummies(heart7,drop_first=True)

# %%
heart_final
# Out:
#      Age  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  MaxHR  \
# 0     40              1        140          289          0           1    172
# 1     49              2        160          180          0           1    156
# 2     37              1        130          283          0           2     98
# 3     48              3        138          214          0           1    108
# 4     54              2        150          195          0           1    122
# ..   ...            ...        ...          ...        ...         ...    ...
# 913   45              4        110          264          0           1    132
# 914   68              3        144          193          1           1    141
# 915   57              3        130          131          0           1    115
# 916   57              1        130          236          0           3    174
# 917   38              2        138          175          0           1    173
#
# ...

# %%
x=heart_final.drop('HeartDisease',axis='columns')
y=heart_final.HeartDisease

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x_scaled,y,random_state=10)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(DecisionTreeClassifier(),x,y,cv=5)

# %%
score.mean()
# Out:
# 0.7366666666666666

# %%
from sklearn.ensemble import BaggingClassifier
bag_model=BaggingClassifier(
base_estimator=DecisionTreeClassifier(),
n_estimators=100,
max_samples=0.8,
oob_score=True,
random_state=0)

# %%
bag_model.fit(X_train,y_train)
# Out:
# C:\Users\Humaina\anaconda3\Lib\site-packages\sklearn\ensemble\_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# BaggingClassifier(base_estimator=DecisionTreeClassifier(), max_samples=0.8,
#                   n_estimators=100, oob_score=True, random_state=0)

# %%
bag_model.oob_score_
# Out:
# 0.8444444444444444

# %%
bag_model.score(X_test,y_test)
# Out:
# 0.8444444444444444

# %%
from sklearn.svm import SVC

# %%
score=cross_val_score(SVC(),x,y,cv=5)

# %%
score.mean()
# Out:
# 0.6911111111111111

# %%
bag_model=BaggingClassifier(
base_estimator=SVC(),
n_estimators=100,
max_samples=0.8,
oob_score=True,
random_state=0)

# %%
bag_model.fit(X_train,y_train)
# Out:
# C:\Users\Humaina\anaconda3\Lib\site-packages\sklearn\ensemble\_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# BaggingClassifier(base_estimator=SVC(), max_samples=0.8, n_estimators=100,
#                   oob_score=True, random_state=0)

# %%
bag_model.oob_score_
# Out:
# 0.8622222222222222

# %%
bag_model.score(X_test,y_test)
# Out:
# 0.8488888888888889

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
scores=cross_val_score(RandomForestClassifier(),x,y,cv=5)

# %%
scores.mean()
# Out:
# 0.8255555555555556
